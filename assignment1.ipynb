# %%
# %pip install pygam
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pygam
#   Downloading pygam-0.12.0-py3-none-any.whl.metadata (9.8 kB)
# Requirement already satisfied: numpy>=1.5.0 in c:\users\fehrb\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pygam) (2.3.2)
# Collecting progressbar2<5,>=4.2.0 (from pygam)
#   Downloading progressbar2-4.5.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: scipy<1.17,>=1.11.1 in c:\users\fehrb\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pygam) (1.16.1)
# Collecting python-utils>=3.8.1 (from progressbar2<5,>=4.2.0->pygam)
#   Downloading python_utils-3.9.1-py2.py3-none-any.whl.metadata (9.8 kB)
# Requirement already satisfied: typing_extensions>3.10.0.2 in c:\program files\positron\resources\app\extensions\positron-python\python_files\lib\ipykernel\py3 (from python-utils>=3.8.1->progressbar2<5,>=4.2.0->pygam) (4.15.0)
# Downloading pygam-0.12.0-py3-none-any.whl (84 kB)
# Downloading progressbar2-4.5.0-py3-none-any.whl (57 kB)
# Downloading python_utils-3.9.1-py2.py3-none-any.whl (32 kB)
# Installing collected packages: python-utils, progressbar2, pygam
#
#    ------------- -------------------------- 1/3 [progressbar2]
#    -------------------------- ------------- 2/3 [pygam]
#    ---------------------------------------- 3/3 [pygam]
#
# Successfully installed progressbar2-4.5.0 pygam-0.12.0 python-utils-3.9.1
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script progressbar.exe is installed in 'C:\Users\fehrb\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
import pandas as pd
from pygam import LinearGAM, s, f, l

# %%
train = pd.read_csv("assignment_data_train.csv")
test = pd.read_csv("assignment_data_test.csv")

# %%
train.dtypes
# Out:
# Timestamp    object
# year          int64
# month         int64
# day           int64
# hour          int64
# trips         int64
# dtype: object

# %%
x = train[['year', 'month', 'day', 'hour']]
y = train['trips']

# %%
model = LinearGAM(s(0) + f(1) + f(2) + f(3))
modelFit = model.gridsearch(x.values, y)
# Out:
# 100% (11 of 11) |########################| Elapsed Time: 0:00:00 Time:  0:00:000:00

# %%
test.columns
# Out:
# Index(['Timestamp', 'year', 'month', 'day', 'hour'], dtype='object')

# %%
pred = modelFit.predict(test[['year', 'month', 'day', 'hour']].values)
